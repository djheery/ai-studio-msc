# %%
# Pandas Introduction

import pandas as pd
import numpy as np

# Series = 1 colum of a dataframe? 
ser = pd.Series()

print(ser)

data = np.array(['g', 'e', 'e', 'k', 's'])
ser = pd.Series(data)

print(ser)
# Out:
# Series([], dtype: float64)
# 0    g
# 1    e
# 2    e
# 3    k
# 4    s
# dtype: object
# /home/danielheery/anaconda3/envs/AI-Studio/lib/python3.7/site-packages/ipykernel_launcher.py:6: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.

# %%
# Dataframes in Pandas 

import pandas as pd 

df = pd.DataFrame()
print(df)

string_list = [
                'Geeks',
                'For',
                'Geeks',
                'is',
                'Portal',
                'for'
                'geeks'
              ]

df = pd.DataFrame(string_list)
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []
#           0
# 0     Geeks
# 1       For
# 2     Geeks
# 3        is
# 4    Portal
# 5  forgeeks

# %%
import pandas as pd 

period_count = 6
test_dates = pd.date_range("20200101", periods=period_count)
data_frame_headers = "ABCDEF"
header_count = len(data_frame_headers)

df = pd.DataFrame(np.random.randn(period_count, header_count), index=test_dates, columns=list(data_frame_headers))

#print(test_dates)
print(df)
# Out:
#                    A         B         C         D         E         F
# 2020-01-01 -1.104213 -1.221151 -0.671519  0.430263  0.272449  2.512474
# 2020-01-02 -1.878794 -0.380528 -0.004252  0.640405  0.180973  0.939587
# 2020-01-03  1.034523  0.867408 -0.551451  1.084592 -0.332648  0.362741
# 2020-01-04 -1.066717  0.777104  0.203271 -1.077014  0.480338  0.698400
# 2020-01-05  0.117207 -0.258645 -1.670309 -1.062551  0.040801  1.371832
# 2020-01-06 -1.613748  0.775158  1.401739  0.964243  0.323305 -0.732497

# %%
import pandas as pd 

dictionary_df = pd.DataFrame(
    {
        "is_hungry": True,
        "last_ate": pd.Timestamp("20221020"),
        "something": pd.Series(1, index=list(range(4)), dtype="int32"),
        "multiply_array": np.array([3] * 4, dtype="float32"),
        "categories": pd.Categorical(["one", "two", "two", "four"]),
        "foo": "bar"
    }
)

dictionary_df

# View the head: 

dictionary_df.head()

# View the tail: 

dictionary_df.tail()

# Accessing a single column

dictionary_df["is_hungry"]

#Getting 

ts = pd.Series(np.random.randn(1000), index=pd.date_range("1/1/2000", periods=1000))

ts = ts.cumsum()

ts.plot()
# Out:
# <AxesSubplot:>

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
# %matplotlib inline

df = pd.DataFrame(
    {
        "Candidate": ["Alex", "Amy", "Boland", "Kamelia", "Lee", "Maryam", "Qasem"],
        "University": ["Northumbria", "Newcastle", "Manchester", "Liverpool", "Edinburgh", "Belfast", "Birmingham"],
        "Age": [23, 24, 31, 29, 34, 41, 35],
        "Exam": [73.0, 78.0, 80.0, 84.0, 72.0, 81.0, 80.0]
    }
)

# Print the Table 
df 

# Print the First five entries 
df[0:5]
df.head()

# Print Last 5 Entries
df.tail()

# Print out all the entries in University Column 
df["University"]

# Print all entries of first row 
df.loc[0]

# Print Entries in the First 3 Rows 
df.loc[0:2]

# Print Data for Alex
df[df["Candidate"] == "Alex"]

# Print Data for Information Related to Amy 
df[df["Candidate"] == "Amy"]

# Describe Age 
df["Age"].describe()

# Age and Exam Describe
df.describe()

# Drop University 
# df.drop(columns="University")

# Drop the First 3 columns
# df.drop([0, 1, 2],  axis=0)

# Plot a bar chart for exam vs candidate

plt.bar(df['Candidate'], df['Exam'])
plt.title('Exam Result')
plt.ylabel('score')
# Out:
# Text(0, 0.5, 'score')
